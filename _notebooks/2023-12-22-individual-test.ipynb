# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: CSP Test Reflection
# description: A reflection on the CSP mc test
# type: tangibles
# courses: { compsci: {week: 1} }
# ---
#
# # CSP Test Reflection
#
# ## Question #’s  I Got Wrong:
# 6	16	18	20	21	22	24	30	32	36	39	41	45	50	56	58	60	62	63	64	65	66	67
#
# ### Question 6:
# The correct answer was C, I chose B because I didn’t think the quiz through enough, and if I had spent time going through the movements, I would have gotten it right.
#
# ### Question 16:
# The answer was D, I chose A because I thought that A would increment the length as in count how many there were removed but I didn't read the code correctly so I messed up on that one.
#
# ### Question 18:
# Honestly, I just was plain stupid on this question, I chose A and the obvious answer was B, A just tells you to move into a wall if you can’t move which doesn’t make any sense.
#
# ### Question 30:
# I followed the code with my digits and after reading it I had thought that it would not be able to say too low but I guess I didn’t try enough digits which would cause me to get that problem wrong.
#
# ### Question 39:
# Code segment shows
# ```
# Line 1: i ← 1
# Line 2: sum ← 0
# Line 3: REPEAT UNTIL (i > 10)
# Line 4: {
# Line 5:    i ← i + 1
# Line 6:    sum ← sum + nums[i]
# Line 7: }
# Line 8: DISPLAY (sum)
# ```
# And I chose A because A says lines 1 and 2 should be interchanged but I guess I can see why 5 and 6 would be interchanged as 5 and 6 if you changed them would result in the intended outcome
#
# ### Question 45:
# Correct answer D, I chose B because I thought that the random would be the results, and like if I had 3 then that meant 3 heads, and if I had 0 that would be all tails, and then if it was 3 or 0 then I won and if it wasn't I loose which isn't correct according to CB.
#
# ### Question 58:
# Correct answer C, for my answer which was A, the check for if x=y would be false, and the else would be false which makes the entire function return false which confuses me cause from what I interpreted from the question, it wants me to find which would return false and I did so that question I have questions for.
#
# ### Question 64:
# For this double question, I chose B and C but the right answer was B and D. This question is another example of why I should slow down and try each question instead of brute forcing it because if I had read through a little further I would have decided that B and D were the right answer. I need to slow down. This applies not just to this question but to the whole quiz.
#
# ### Question 67:
# I chose A and C, the answer was A and B. A is right because it causes the output to equal 1 when in actuality it should be 2 and B is the right answer because it causes the output to be 0 when it should be 1. Both of these show the flaw in the code's current configuration and if I spent more time and did the code in my head I would have gotten it right.
#
# Looking at my quiz results and reflections, it's clear I can do better next time. I didn’t spend a lot of time on each question to complete them as fast as possible. Next time, I'll slow down, take some time to understand each question, and not rush to answer. The coding questions, like Question 18, made me realize I should take more time on code questions and that It's not just about glances. Mistakes on questions like 30 and 39 showed me I need a lot more hands-on practice with code segments and purposely messing up. I should spend more time working through various scenarios to build up my skills and intuition.  Overall I need to consider slowing down, being extra careful with code, and practicing more will be my game plan for taking these quizzes next time.
